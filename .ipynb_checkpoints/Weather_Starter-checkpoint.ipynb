# %%
import requests
from pprint import pprint
import pandas as pd
import numpy as np

# %%
# Replace with your desired latitude and longitude
latitude = '38.685066'
longitude = '-90.349317'

# Construct API endpoint URL
url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Construct the API endpoint URL for the given point
point_url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Make a GET request to the API for the given point
point_response = requests.get(point_url)

# Check if the request was successful
if point_response.status_code == 200:
    
    # Parse the JSON response
    point_data = point_response.json()
    pprint(point_data)
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'bearing': {'@type': 's:QuantitativeValue'},
#                'city': 's:addressLocality',
#                'county': {'@type': '@id'},
#                'distance': {'@id': 's:Distance',
#                             '@type': 's:QuantitativeValue'},
#                'forecastGridData': {'@type': '@id'},
#                'forecastOffice': {'@type': '@id'},
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'geometry': {'@id': 's:GeoCoordinates',
#                             '@type': 'geo:wktLiteral'},
#                'publicZone': {'@type': '@id'},
#                's': 'https://schema.org/',
#                'state': 's:addressRegion',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#                'value': {'@id': 's:value'},
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [-90.3493, 38.6851], 'type': 'Point'},
#  'id': 'https://api.weather.gov/points/38.6851,-90.3493',
#  'properties': {'@id': 'https://api.weather.gov/points/38.6851,-90.3493',
#                 '@type': 'wx:Point',
#                 'county': 'https://api.weather.gov/zones/county/MOC189',
#                 'cwa': 'LSX',
#                 'fireWeatherZone': 'https://api.weather.gov/zones/fire/MOZ063',
#                 'forecast': 'https://api.weather.gov/gridpoints/LSX/90,77/forecast',
#                 'forecastGridData': 'https://api.weather.gov/gridpoints/LSX/90,77',
#                 'forecastHourly': 'https://api.weather.gov/gridpoints/LSX/90,77/forecast/hourly',
#                 'forecastOffice': 'https://api.weather.gov/offices/LSX',
#                 'forecastZone': 'https://api.weather.gov/zones/forecast/MOZ063',
#                 'gridId': 'LSX',
#                 'gridX': 90,
#                 'gridY': 77,
#                 'observationStations': 'https://api.weather.gov/gridpoints/LSX/90,77/stations',
#                 'radarStation': 'KLSX',
#                 'relativeLocation': {'geometry': {'coordinates': [-90.340013,
#                                                                   38.68911],
#                                                   'type': 'Point'},
#                                      'properties': {'bearing': {'unitCode': 'wmoUnit:degree_(angle)',
#                                                                 'value': 241},
#                                                     'city': 'Vinita Park',
#                                                     'distance': {'unitCode': 'wmoUnit:m',
#                                                                  'value': 921.17913613927},
#                                                     'state': 'MO'},
#                                      'type': 'Feature'},
#                 'timeZone': 'America/Chicago'},
#  'type': 'Feature'}

# %%
# Replace with your desired latitude and longitude
latitude = '38.685066'
longitude = '-90.349317'

# Construct API endpoint URL
url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Construct the API endpoint URL for the given point
point_url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Make a GET request to the API for the given point
point_response = requests.get(point_url)

# Check if the request was successful
if point_response.status_code == 200:
    
    # Parse the JSON response
    point_data = point_response.json()

    # Extract the hourly forecast URL
    hourly_forecast_url = point_data['properties']['forecast']

    # Make a GET request to the hourly forecast URL
    hourly_forecast_response = requests.get(hourly_forecast_url)

    # Check if the hourly forecast request was successful
    if hourly_forecast_response.status_code == 200:
        # Parse the JSON response
        hourly_forecast_data = hourly_forecast_response.json()

        # Now hourly_forecast_data contains the hourly forecast information
        # You can print it out or process it as needed
        pprint(hourly_forecast_data)
    else:
        print(f'Error retrieving hourly forecast: {hourly_forecast_response.status_code}')
else:
    print(f'Error retrieving point data: {point_response.status_code}')
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [[[-90.3562231, 38.7005791],
#                                [-90.35719519999999, 38.6784337],
#                                [-90.32881509999999, 38.6776724],
#                                [-90.32783709999998, 38.699817599999996],
#                                [-90.3562231, 38.7005791]]],
#               'type': 'Polygon'},
#  'properties': {'elevation': {'unitCode': 'wmoUnit:m', 'value': 180.1368},
#                 'forecastGenerator': 'BaselineForecastGenerator',
#                 'generatedAt': '2023-11-17T02:23:04+00:00',
#                 'periods': [{'detailedForecast': 'A slight chance of rain '
#                                                  'after 3am. Cloudy. Low '
#                                                  'around 53, with temperatures '
#                                                  'rising to around 59 '
#                                                  'overnight. Southwest wind '
#                                                  'around 9 mph. Chance of '
#                                                  'precipitation is 20%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc/rain,20?size=medium',
#                              'isDaytime': False,
#                              'name': 'Tonight',
#                              'number': 1,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 20},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 87},
#                              'shortForecast': 'Cloudy then Slight Chance Light '
#                                               'Rain',
#                              'startTime': '2023-11-16T20:00:00-06:00',
#                              'temperature': 53,
#                              'temperatureTrend': 'rising',
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': 'A slight chance of rain '
#                                                  'before 10am. Partly sunny. '
#                                                  'High near 61, with '
#                                                  'temperatures falling to '
#                                                  'around 52 in the afternoon. '
#                                                  'Northwest wind 7 to 13 mph. '
#                                                  'Chance of precipitation is '
#                                                  '20%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,20/bkn?size=medium',
#                              'isDaytime': True,
#                              'name': 'Friday',
#                              'number': 2,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 20},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 87},
#                              'shortForecast': 'Slight Chance Light Rain then '
#                                               'Partly Sunny',
#                              'startTime': '2023-11-17T06:00:00-06:00',
#                              'temperature': 61,
#                              'temperatureTrend': 'falling',
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '7 to 13 mph'},
#                             {'detailedForecast': 'Clear, with a low around 32. '
#                                                  'North wind 2 to 9 mph.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-18T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#                              'isDaytime': False,
#                              'name': 'Friday Night',
#                              'number': 3,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 56},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T18:00:00-06:00',
#                              'temperature': 32,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '2 to 9 mph'},
#                             {'detailedForecast': 'Sunny. High near 55, with '
#                                                  'temperatures falling to '
#                                                  'around 50 in the afternoon. '
#                                                  'West wind 2 to 6 mph.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.888888888888889},
#                              'endTime': '2023-11-18T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#                              'isDaytime': True,
#                              'name': 'Saturday',
#                              'number': 4,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 61},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-18T06:00:00-06:00',
#                              'temperature': 55,
#                              'temperatureTrend': 'falling',
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '2 to 6 mph'},
#                             {'detailedForecast': 'Clear, with a low around 36. '
#                                                  'South wind around 5 mph.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -4.444444444444445},
#                              'endTime': '2023-11-19T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#                              'isDaytime': False,
#                              'name': 'Saturday Night',
#                              'number': 5,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 59},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-18T18:00:00-06:00',
#                              'temperature': 36,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': 'Mostly sunny. High near 58, '
#                                                  'with temperatures falling to '
#                                                  'around 53 in the afternoon.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-19T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#                              'isDaytime': True,
#                              'name': 'Sunday',
#                              'number': 6,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 59},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-19T06:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': 'falling',
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 to 12 mph'},
#                             {'detailedForecast': 'A chance of rain. Mostly '
#                                                  'cloudy, with a low around '
#                                                  '44. Chance of precipitation '
#                                                  'is 40%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 1.6666666666666667},
#                              'endTime': '2023-11-20T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,20/rain,40?size=medium',
#                              'isDaytime': False,
#                              'name': 'Sunday Night',
#                              'number': 7,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 40},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 68},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-19T18:00:00-06:00',
#                              'temperature': 44,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': 'Rain. Mostly cloudy, with a '
#                                                  'high near 51. Chance of '
#                                                  'precipitation is 80%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 7.777777777777778},
#                              'endTime': '2023-11-20T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,50/rain,80?size=medium',
#                              'isDaytime': True,
#                              'name': 'Monday',
#                              'number': 8,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 80},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 86},
#                              'shortForecast': 'Light Rain',
#                              'startTime': '2023-11-20T06:00:00-06:00',
#                              'temperature': 51,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'E',
#                              'windSpeed': '14 mph'},
#                             {'detailedForecast': 'Rain. Cloudy, with a low '
#                                                  'around 42. Chance of '
#                                                  'precipitation is 80%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 8.333333333333334},
#                              'endTime': '2023-11-21T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,80/rain,60?size=medium',
#                              'isDaytime': False,
#                              'name': 'Monday Night',
#                              'number': 9,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 80},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 100},
#                              'shortForecast': 'Light Rain',
#                              'startTime': '2023-11-20T18:00:00-06:00',
#                              'temperature': 42,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '14 mph'},
#                             {'detailedForecast': 'A chance of rain. Mostly '
#                                                  'cloudy, with a high near 49. '
#                                                  'Chance of precipitation is '
#                                                  '50%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 6.666666666666667},
#                              'endTime': '2023-11-21T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,50/rain,40?size=medium',
#                              'isDaytime': True,
#                              'name': 'Tuesday',
#                              'number': 10,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 50},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 96},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-21T06:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '15 to 20 mph'},
#                             {'detailedForecast': 'Partly cloudy, with a low '
#                                                  'around 32.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0.5555555555555556},
#                              'endTime': '2023-11-22T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#                              'isDaytime': False,
#                              'name': 'Tuesday Night',
#                              'number': 11,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 70},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-21T18:00:00-06:00',
#                              'temperature': 32,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '13 to 18 mph'},
#                             {'detailedForecast': 'Sunny, with a high near 42.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -4.444444444444445},
#                              'endTime': '2023-11-22T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#                              'isDaytime': True,
#                              'name': 'Wednesday',
#                              'number': 12,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 66},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-22T06:00:00-06:00',
#                              'temperature': 42,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '13 to 16 mph'},
#                             {'detailedForecast': 'Mostly clear, with a low '
#                                                  'around 27.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -6.111111111111111},
#                              'endTime': '2023-11-23T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=medium',
#                              'isDaytime': False,
#                              'name': 'Wednesday Night',
#                              'number': 13,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 61},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T18:00:00-06:00',
#                              'temperature': 27,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 to 15 mph'},
#                             {'detailedForecast': 'Sunny, with a high near 39.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -7.777777777777778},
#                              'endTime': '2023-11-23T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#                              'isDaytime': True,
#                              'name': 'Thanksgiving Day',
#                              'number': 14,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-23T06:00:00-06:00',
#                              'temperature': 39,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '13 mph'}],
#                 'units': 'us',
#                 'updateTime': '2023-11-16T23:07:17+00:00',
#                 'updated': '2023-11-16T23:07:17+00:00',
#                 'validTimes': '2023-11-16T17:00:00+00:00/P7DT8H'},
#  'type': 'Feature'}

# %%
# Replace with your desired latitude and longitude
latitude = '38.685066'
longitude = '-90.349317'

# Construct API endpoint URL
url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Construct the API endpoint URL for the given point
point_url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Make a GET request to the API for the given point
point_response = requests.get(point_url)

# Check if the request was successful
if point_response.status_code == 200:
    
    # Parse the JSON response
    point_data = point_response.json()

    # Extract the hourly forecast URL
    hourly_forecast_url = point_data['properties']['forecastHourly']

    # Make a GET request to the hourly forecast URL
    hourly_forecast_response = requests.get(hourly_forecast_url)

    # Check if the hourly forecast request was successful
    if hourly_forecast_response.status_code == 200:
        # Parse the JSON response
        hourly_forecast_data = hourly_forecast_response.json()

        # Now hourly_forecast_data contains the hourly forecast information
        # You can print it out or process it as needed
        pprint(hourly_forecast_data)
    else:
        print(f'Error retrieving hourly forecast: {hourly_forecast_response.status_code}')
else:
    print(f'Error retrieving point data: {point_response.status_code}')
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [[[-90.3562231, 38.7005791],
#                                [-90.35719519999999, 38.6784337],
#                                [-90.32881509999999, 38.6776724],
#                                [-90.32783709999998, 38.699817599999996],
#                                [-90.3562231, 38.7005791]]],
#               'type': 'Polygon'},
#  'properties': {'elevation': {'unitCode': 'wmoUnit:m', 'value': 180.1368},
#                 'forecastGenerator': 'HourlyForecastGenerator',
#                 'generatedAt': '2023-11-17T02:23:05+00:00',
#                 'periods': [{'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-16T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 1,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 65},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-16T20:00:00-06:00',
#                              'temperature': 65,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-16T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,4?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 2,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 4},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 70},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-16T21:00:00-06:00',
#                              'temperature': 63,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-16T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 3,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 70},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-16T22:00:00-06:00',
#                              'temperature': 63,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 4,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 72},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-16T23:00:00-06:00',
#                              'temperature': 63,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 5,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 81},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-17T00:00:00-06:00',
#                              'temperature': 60,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,9?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 6,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 9},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 81},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-17T01:00:00-06:00',
#                              'temperature': 60,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,12?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 7,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 12},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 84},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-17T02:00:00-06:00',
#                              'temperature': 60,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,17?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 8,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 17},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 87},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T03:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,22?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 9,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 22},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 87},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T04:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,22?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 10,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 22},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 87},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T05:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,21?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 11,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 21},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 87},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T06:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,21?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 12,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 21},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 86},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T07:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-17T09:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,20?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 13,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 20},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 83},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T08:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10},
#                              'endTime': '2023-11-17T10:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,16?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 14,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 16},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 75},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T09:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 8.333333333333334},
#                              'endTime': '2023-11-17T11:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/ovc,13?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 15,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 13},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 69},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-17T10:00:00-06:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 6.111111111111111},
#                              'endTime': '2023-11-17T12:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn,7?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 16,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 7},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 59},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-17T11:00:00-06:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5},
#                              'endTime': '2023-11-17T13:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 17,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 2},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 55},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-17T12:00:00-06:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.3333333333333335},
#                              'endTime': '2023-11-17T14:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 18,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 2},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 51},
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2023-11-17T13:00:00-06:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 2.2222222222222223},
#                              'endTime': '2023-11-17T15:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct,2?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 19,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 2},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 47},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-17T14:00:00-06:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '13 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 1.1111111111111112},
#                              'endTime': '2023-11-17T16:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,1?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 20,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 43},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-17T15:00:00-06:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0},
#                              'endTime': '2023-11-17T17:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 21,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 43},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-17T16:00:00-06:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-17T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 22,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 43},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-17T17:00:00-06:00',
#                              'temperature': 52,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-17T19:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 23,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 46},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T18:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.3333333333333335},
#                              'endTime': '2023-11-17T20:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 24,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 43},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T19:00:00-06:00',
#                              'temperature': 47,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.888888888888889},
#                              'endTime': '2023-11-17T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 25,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 45},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T20:00:00-06:00',
#                              'temperature': 45,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -4.444444444444445},
#                              'endTime': '2023-11-17T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 26,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 45},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T21:00:00-06:00',
#                              'temperature': 44,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -5},
#                              'endTime': '2023-11-17T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 27,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 46},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T22:00:00-06:00',
#                              'temperature': 42,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -5.555555555555555},
#                              'endTime': '2023-11-18T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 28,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 46},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T23:00:00-06:00',
#                              'temperature': 41,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -5.555555555555555},
#                              'endTime': '2023-11-18T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 29,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 48},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-18T00:00:00-06:00',
#                              'temperature': 40,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -6.111111111111111},
#                              'endTime': '2023-11-18T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 30,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 50},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-18T01:00:00-06:00',
#                              'temperature': 38,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -5.555555555555555},
#                              'endTime': '2023-11-18T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 31,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 54},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-18T02:00:00-06:00',
#                              'temperature': 37,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -5.555555555555555},
#                              'endTime': '2023-11-18T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 32,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 54},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-18T03:00:00-06:00',
#                              'temperature': 37,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -6.111111111111111},
#                              'endTime': '2023-11-18T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 33,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 56},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-18T04:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -6.111111111111111},
#                              'endTime': '2023-11-18T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 34,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 56},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-18T05:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '2 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -5.555555555555555},
#                              'endTime': '2023-11-18T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 35,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 61},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-18T06:00:00-06:00',
#                              'temperature': 34,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '2 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -4.444444444444445},
#                              'endTime': '2023-11-18T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 36,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 61},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-18T07:00:00-06:00',
#                              'temperature': 36,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '2 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.888888888888889},
#                              'endTime': '2023-11-18T09:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 37,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 59},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-18T08:00:00-06:00',
#                              'temperature': 38,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.888888888888889},
#                              'endTime': '2023-11-18T10:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 38,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 52},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-18T09:00:00-06:00',
#                              'temperature': 41,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -4.444444444444445},
#                              'endTime': '2023-11-18T11:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 39,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 45},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-18T10:00:00-06:00',
#                              'temperature': 44,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -5.555555555555555},
#                              'endTime': '2023-11-18T12:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 40,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
# ...
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '15 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -6.111111111111111},
#                              'endTime': '2023-11-22T20:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 144,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 56},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T19:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '14 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -6.666666666666667},
#                              'endTime': '2023-11-22T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 145,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 56},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T20:00:00-06:00',
#                              'temperature': 34,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '13 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -6.666666666666667},
#                              'endTime': '2023-11-22T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 146,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T21:00:00-06:00',
#                              'temperature': 33,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -7.222222222222222},
#                              'endTime': '2023-11-22T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 147,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T22:00:00-06:00',
#                              'temperature': 32,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -7.222222222222222},
#                              'endTime': '2023-11-23T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 148,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 61},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T23:00:00-06:00',
#                              'temperature': 31,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -7.777777777777778},
#                              'endTime': '2023-11-23T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 149,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-23T00:00:00-06:00',
#                              'temperature': 31,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -7.777777777777778},
#                              'endTime': '2023-11-23T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 150,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-23T01:00:00-06:00',
#                              'temperature': 31,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -8.333333333333334},
#                              'endTime': '2023-11-23T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 151,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-23T02:00:00-06:00',
#                              'temperature': 30,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -8.333333333333334},
#                              'endTime': '2023-11-23T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 152,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-23T03:00:00-06:00',
#                              'temperature': 30,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -8.333333333333334},
#                              'endTime': '2023-11-23T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 153,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 60},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-23T04:00:00-06:00',
#                              'temperature': 29,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -8.88888888888889},
#                              'endTime': '2023-11-23T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 154,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-23T05:00:00-06:00',
#                              'temperature': 29,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -8.88888888888889},
#                              'endTime': '2023-11-23T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 155,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-23T06:00:00-06:00',
#                              'temperature': 29,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -8.333333333333334},
#                              'endTime': '2023-11-23T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 156,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-23T07:00:00-06:00',
#                              'temperature': 30,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'}],
#                 'units': 'us',
#                 'updateTime': '2023-11-16T23:07:17+00:00',
#                 'updated': '2023-11-16T23:07:17+00:00',
#                 'validTimes': '2023-11-16T17:00:00+00:00/P7DT8H'},
#  'type': 'Feature'}

# %%
df = pd.read_csv('https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station=IKV&data=all&year1=2023&month1=1&day1=1&year2=2023&month2=11&day2=15&tz=Etc%2FUTC&format=onlycomma&latlon=no&elev=no&missing=M&trace=T&direct=no&report_type=3&report_type=4')
df.head()
# Out:
#   station             valid   tmpf   dwpf    relh    drct  sknt  p01i   alti  \
# 0     IKV  2023-01-01 00:15  35.60  33.80   93.08    0.00  0.00   0.0  29.75
# 1     IKV  2023-01-01 00:35  35.60  32.00   86.59  120.00  4.00   0.0  29.75
# 2     IKV  2023-01-01 00:55  33.80  32.00   93.03  130.00  5.00   0.0  29.75
# 3     IKV  2023-01-01 01:15  33.80  33.80  100.00    0.00  0.00   0.0  29.76
# 4     IKV  2023-01-01 01:35  33.80  32.00   93.03   40.00  4.00   0.0  29.76
#
#   mslp  ... wxcodes ice_accretion_1hr ice_accretion_3hr ice_accretion_6hr  \
# 0    M  ...       M                 M                 M                 M
# 1    M  ...       M                 M                 M                 M
# 2    M  ...       M                 M                 M                 M
# 3    M  ...       M                 M                 M                 M
# 4    M  ...       M                 M                 M                 M
#
#   peak_wind_gust peak_wind_drct peak_wind_time   feel  \
# 0              M              M              M  35.60
# 1              M              M              M  31.62
# 2              M              M              M  28.53
# 3              M              M              M  33.80
# 4              M              M              M  29.52
#
#                                                metar snowdepth
# 0  KIKV 010015Z AUTO 00000KT 10SM CLR 02/01 A2975...         M
# 1  KIKV 010035Z AUTO 12004KT 10SM BKN100 BKN120 0...         M
# 2  KIKV 010055Z AUTO 13005KT 9SM OVC100 01/00 A29...         M
# 3  KIKV 010115Z AUTO 00000KT 9SM FEW075 OVC100 01...         M
# 4  KIKV 010135Z AUTO 04004KT 9SM FEW075 OVC100 01...         M
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['station', 'valid', 'tmpf', 'dwpf', 'relh', 'drct', 'sknt', 'p01i',
#        'alti', 'mslp', 'vsby', 'gust', 'skyc1', 'skyc2', 'skyc3', 'skyc4',
#        'skyl1', 'skyl2', 'skyl3', 'skyl4', 'wxcodes', 'ice_accretion_1hr',
#        'ice_accretion_3hr', 'ice_accretion_6hr', 'peak_wind_gust',
#        'peak_wind_drct', 'peak_wind_time', 'feel', 'metar', 'snowdepth'],
#       dtype='object')

# %%
# I/relh - F/relativeHumidity
# I/tmpf - F/Temperature
# I/dwpf - F/dewpoint-> value
# I/sknt - F/windSpeed
# I/skyc1 - F/shortForecast
# I/valid - F/isDaytime
# I/p01i - F/probabilityOfPercipitation -> value

# %%
historic_weather = df.drop(columns = ['valid','station','drct',
       'alti', 'mslp', 'vsby', 'gust',
       'skyl1', 'skyl2', 'skyl3', 'skyl4', 'wxcodes', 'skyc2', 'skyc3', 'skyc4', 'ice_accretion_1hr',
       'ice_accretion_3hr', 'ice_accretion_6hr', 'peak_wind_gust',
       'peak_wind_drct', 'peak_wind_time', 'feel', 'metar', 'snowdepth'])
historic_weather.dtypes
# Out:
# tmpf      object
# dwpf      object
# relh      object
# sknt      object
# p01i     float64
# skyc1     object
# dtype: object

# %%
# Round imported columns to 0 decimals places so that it works with the other dataframe

# Drop the nans
historic_weather.dropna(inplace=True)

# Make the strings as numbers
historic_weather['tmpf'] = pd.to_numeric(historic_weather['tmpf'], errors='coerce')
historic_weather['dwpf'] = pd.to_numeric(historic_weather['dwpf'], errors='coerce')
historic_weather['relh'] = pd.to_numeric(historic_weather['relh'], errors='coerce')
historic_weather['sknt'] = pd.to_numeric(historic_weather['sknt'], errors='coerce')
historic_weather['p01i'] = pd.to_numeric(historic_weather['p01i'], errors='coerce')

# Round the numbers
historic_weather['tmpf'] = historic_weather['tmpf'].round(0)
historic_weather['dwpf'] = historic_weather['dwpf'].round(0)
historic_weather['relh'] = historic_weather['relh'].round(0)
historic_weather['sknt'] = historic_weather['sknt'].round(0)
historic_weather['p01i'] = historic_weather['p01i'].round(0)

historic_weather = historic_weather[['tmpf','dwpf','relh','p01i','skyc1','sknt']]
historic_weather.head()
# Out:
#    tmpf  dwpf   relh  p01i skyc1  sknt
# 0  36.0  34.0   93.0   0.0   CLR   0.0
# 1  36.0  32.0   87.0   0.0   BKN   4.0
# 2  34.0  32.0   93.0   0.0   OVC   5.0
# 3  34.0  34.0  100.0   0.0   FEW   0.0
# 4  34.0  32.0   93.0   0.0   FEW   4.0

# %%
forecast  = []

periods_data = hourly_forecast_data['properties']['periods']
for period in periods_data:
    forecast.append({
        'Temperature':period['temperature'],
        'Dewpoint': period['dewpoint']['value'],
        'Relative Humidity': period['relativeHumidity']['value'],
        'Probability of Percipitation':period['probabilityOfPrecipitation']['value'],
        'Short Forecast': period['shortForecast'],
        'Wind Speed': period['windSpeed'],
#         'Is Daytime':period['isDaytime'], 
    })
forecast_weather = pd.DataFrame(forecast)
forecast_weather.head()
# Out:
#    Temperature   Dewpoint  Relative Humidity  Probability of Percipitation  \
# 0           65  11.666667                 65                             3
# 1           63  11.666667                 70                             4
# 2           63  11.666667                 70                             6
# 3           63  12.222222                 72                             6
# 4           60  12.222222                 81                             6
#
#   Short Forecast Wind Speed
# 0         Cloudy      8 mph
# 1         Cloudy      8 mph
# 2         Cloudy      9 mph
# 3         Cloudy      9 mph
# 4         Cloudy      9 mph

# %%
forecast_weather['Short Forecast'].unique()
# Out:
# array(['Cloudy', 'Slight Chance Light Rain', 'Mostly Cloudy',
#        'Partly Sunny', 'Mostly Sunny', 'Sunny', 'Clear', 'Mostly Clear',
#        'Chance Light Rain', 'Light Rain', 'Light Rain Likely',
#        'Partly Cloudy'], dtype=object)

# %%
# Map out the Short Forecast to match the other column
def mapping_forecast(forecast):
    mapping = {'Mostly Clear': 'FEW',
        'Partly Cloudy': 'SCT',
        'Clear': 'CLR',
        'Sunny': 'CLR',
        'Mostly Sunny': 'FEW',
        'Partly Sunny': 'SCT',
        'Mostly Cloudy': 'BKN',
        'Cloudy': 'OVC',
        'Chance Rain Showers': 'SCT',
        'Slight Chance Light Rain': 'SCT',
        'Chance Light Rain': 'SCT',
        'Light Rain Likely': 'BKN'
    }
    return mapping.get(forecast, 'Unknown')

forecast_weather['Short Forecast'] = forecast_weather['Short Forecast'].apply(mapping_forecast)

# Drop 'Unknown' and 'VV'
forecast_weather = forecast_weather[~forecast_weather['Short Forecast'].isin(['Unknown', 'VV'])]
forecast_weather.head()
# Out:
#    Temperature   Dewpoint  Relative Humidity  Probability of Percipitation  \
# 0           65  11.666667                 65                             3
# 1           63  11.666667                 70                             4
# 2           63  11.666667                 70                             6
# 3           63  12.222222                 72                             6
# 4           60  12.222222                 81                             6
#
#   Short Forecast Wind Speed
# 0            OVC      8 mph
# 1            OVC      8 mph
# 2            OVC      9 mph
# 3            OVC      9 mph
# 4            OVC      9 mph

# %%
forecast_weather.dtypes
# Out:
# Temperature                       int64
# Dewpoint                        float64
# Relative Humidity                 int64
# Probability of Percipitation      int64
# Short Forecast                   object
# Wind Speed                       object
# dtype: object

# %%
# Pull out the Wind Speed
forecast_weather['Wind Speed'] = forecast_weather['Wind Speed'].str.extract('(\d+)').astype(int)
forecast_weather['Wind Speed (Knots)'] = forecast_weather['Wind Speed']* 0.8689762
forecast_weather.drop(columns = ['Wind Speed'], inplace = True)

# %%
forecast_weather.head()
# Out:
#    Temperature   Dewpoint  Relative Humidity  Probability of Percipitation  \
# 0           65  11.666667                 65                             3
# 1           63  11.666667                 70                             4
# 2           63  11.666667                 70                             6
# 3           63  12.222222                 72                             6
# 4           60  12.222222                 81                             6
#
#   Short Forecast  Wind Speed (Knots)
# 0            OVC            6.951810
# 1            OVC            6.951810
# 2            OVC            7.820786
# 3            OVC            7.820786
# 4            OVC            7.820786

# %%
### That concludes our dataset formatting ###

# %%
historic_weather.head()
# Out:
#    tmpf  dwpf   relh  p01i skyc1  sknt
# 0  36.0  34.0   93.0   0.0   CLR   0.0
# 1  36.0  32.0   87.0   0.0   BKN   4.0
# 2  34.0  32.0   93.0   0.0   OVC   5.0
# 3  34.0  34.0  100.0   0.0   FEW   0.0
# 4  34.0  32.0   93.0   0.0   FEW   4.0

# %%
forecast_weather.head()
# Out:
#    Temperature   Dewpoint  Relative Humidity  Probability of Percipitation  \
# 0           65  11.666667                 65                             3
# 1           63  11.666667                 70                             4
# 2           63  11.666667                 70                             6
# 3           63  12.222222                 72                             6
# 4           60  12.222222                 81                             6
#
#   Short Forecast  Wind Speed (Knots)
# 0            OVC            6.951810
# 1            OVC            6.951810
# 2            OVC            7.820786
# 3            OVC            7.820786
# 4            OVC            7.820786

# %%
historic_weather['H/F'] = 'H'

historic_weather = historic_weather.rename(columns = {'tmpf':'Temperature','dwpf':'Dewpoint','relh':'Relative Humidity',
                                                     'p01i':'Probability of Percipitation','skyc1':'Short Forecast',
                                                     'sknt':'Wind Speed (Knots)'})
historic_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22618 entries, 0 to 22617
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Temperature                   22606 non-null  float64
#  1   Dewpoint                      22606 non-null  float64
#  2   Relative Humidity             22606 non-null  float64
#  3   Probability of Percipitation  22618 non-null  float64
#  4   Short Forecast                22618 non-null  object
#  5   Wind Speed (Knots)            22486 non-null  float64
#  6   H/F                           22618 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 1.2+ MB

# %%
forecast_weather['H/F'] = 'F'
forecast_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 155
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Temperature                   144 non-null    int64
#  1   Dewpoint                      144 non-null    float64
#  2   Relative Humidity             144 non-null    int64
#  3   Probability of Percipitation  144 non-null    int64
#  4   Short Forecast                144 non-null    object
#  5   Wind Speed (Knots)            144 non-null    float64
#  6   H/F                           144 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 9.0+ KB

# %%
complete_df = pd.concat([historic_weather, forecast_weather])
complete_df.dropna(inplace = True)
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22627 entries, 0 to 155
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Temperature                   22627 non-null  float64
#  1   Dewpoint                      22627 non-null  float64
#  2   Relative Humidity             22627 non-null  float64
#  3   Probability of Percipitation  22627 non-null  float64
#  4   Short Forecast                22627 non-null  object
#  5   Wind Speed (Knots)            22627 non-null  float64
#  6   H/F                           22627 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 1.4+ MB

# %%
complete_df = complete_df.reset_index(drop=True)

complete_df = complete_df[
    (complete_df['Short Forecast'] == 'CLR') |
    (complete_df['Short Forecast'] == 'FEW') |
    (complete_df['Short Forecast'] == 'SCT') |
    (complete_df['Short Forecast'] == 'BKN') |
    (complete_df['Short Forecast'] == 'OVC')
]

complete_df.tail()
# Out:
#        Temperature  Dewpoint  Relative Humidity  Probability of Percipitation  \
# 22622         30.0 -8.333333               58.0                           1.0
# 22623         29.0 -8.333333               60.0                           1.0
# 22624         29.0 -8.888889               58.0                           1.0
# 22625         29.0 -8.888889               58.0                           0.0
# 22626         30.0 -8.333333               58.0                           0.0
#
#       Short Forecast  Wind Speed (Knots) H/F
# 22622            FEW           10.427714   F
# 22623            FEW           10.427714   F
# 22624            FEW           10.427714   F
# 22625            CLR           10.427714   F
# 22626            CLR           10.427714   F

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
complete_df[['Temperature','Dewpoint','Relative Humidity','Probability of Percipitation']] = scaler.fit_transform(complete_df[['Temperature','Dewpoint','Relative Humidity','Probability of Percipitation']])
complete_df.head()
# Out:
#    Temperature  Dewpoint  Relative Humidity  Probability of Percipitation  \
# 0    -0.902783 -0.492734           1.079964                     -0.045727
# 1    -0.902783 -0.598034           0.792085                     -0.045727
# 2    -1.000587 -0.598034           1.079964                     -0.045727
# 3    -1.000587 -0.492734           1.415823                     -0.045727
# 4    -1.000587 -0.598034           1.079964                     -0.045727
#
#   Short Forecast  Wind Speed (Knots) H/F
# 0            CLR                 0.0   H
# 1            BKN                 4.0   H
# 2            OVC                 5.0   H
# 3            FEW                 0.0   H
# 4            FEW                 4.0   H

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(drop='first')
complete_df =pd.get_dummies(complete_df, columns = ['Short Forecast'], drop_first = True)
complete_df.head()
# Out:
#    Temperature  Dewpoint  Relative Humidity  Probability of Percipitation  \
# 0    -0.902783 -0.492734           1.079964                     -0.045727
# 1    -0.902783 -0.598034           0.792085                     -0.045727
# 2    -1.000587 -0.598034           1.079964                     -0.045727
# 3    -1.000587 -0.492734           1.415823                     -0.045727
# 4    -1.000587 -0.598034           1.079964                     -0.045727
#
#    Wind Speed (Knots) H/F  Short Forecast_CLR  Short Forecast_FEW  \
# 0                 0.0   H                   1                   0
# 1                 4.0   H                   0                   0
# 2                 5.0   H                   0                   0
# 3                 0.0   H                   0                   1
# 4                 4.0   H                   0                   1
#
#    Short Forecast_OVC  Short Forecast_SCT
# 0                   0                   0
# 1                   0                   0
# 2                   1                   0
# 3                   0                   0
# 4                   0                   0

# %%
X_train = complete_df[completed_df['H/F'] == 'H'].drop(columns = 'Wind Speed (Knots)')
X_test = complete_df[completed_df['H/F'] == 'F'].drop(columns = 'Wind Speed (Knots)')
y_train = complete_df[completed_df['H/F'] == 'H']['Wind Speed (Knots)']
y_test = complete_df[completed_df['H/F'] == 'F']['Wind Speed (Knots)']
# Out:
# C:\Users\swsho\AppData\Local\Temp\ipykernel_9188\2407379278.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   X_train = complete_df[completed_df['H/F'] == 'H'].drop(columns = 'Wind Speed (Knots)')
# C:\Users\swsho\AppData\Local\Temp\ipykernel_9188\2407379278.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   X_test = complete_df[completed_df['H/F'] == 'F'].drop(columns = 'Wind Speed (Knots)')
# C:\Users\swsho\AppData\Local\Temp\ipykernel_9188\2407379278.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y_train = complete_df[completed_df['H/F'] == 'H']['Wind Speed (Knots)']
# C:\Users\swsho\AppData\Local\Temp\ipykernel_9188\2407379278.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y_test = complete_df[completed_df['H/F'] == 'F']['Wind Speed (Knots)']
# 22483    6.951810
# 22484    6.951810
# 22485    7.820786
# 22486    7.820786
# 22487    7.820786
# Name: Wind Speed (Knots), dtype: float64
