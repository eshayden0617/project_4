# %%
import requests
from pprint import pprint

# %%
# Replace with your desired latitude and longitude
latitude = '38.685066'
longitude = '-90.349317'

# Construct API endpoint URL
url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Construct the API endpoint URL for the given point
point_url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Make a GET request to the API for the given point
point_response = requests.get(point_url)

# Check if the request was successful
if point_response.status_code == 200:
    # Parse the JSON response
    point_data = point_response.json()

    # Extract the hourly forecast URL
    hourly_forecast_url = point_data['properties']['forecastHourly']

    # Make a GET request to the hourly forecast URL
    hourly_forecast_response = requests.get(hourly_forecast_url)

    # Check if the hourly forecast request was successful
    if hourly_forecast_response.status_code == 200:
        # Parse the JSON response
        hourly_forecast_data = hourly_forecast_response.json()

        # Now hourly_forecast_data contains the hourly forecast information
        # You can print it out or process it as needed
        pprint(hourly_forecast_data)
    else:
        print(f'Error retrieving hourly forecast: {hourly_forecast_response.status_code}')
else:
    print(f'Error retrieving point data: {point_response.status_code}')
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [[[-90.3562231, 38.7005791],
#                                [-90.35719519999999, 38.6784337],
#                                [-90.32881509999999, 38.6776724],
#                                [-90.32783709999998, 38.699817599999996],
#                                [-90.3562231, 38.7005791]]],
#               'type': 'Polygon'},
#  'properties': {'elevation': {'unitCode': 'wmoUnit:m', 'value': 180.1368},
#                 'forecastGenerator': 'HourlyForecastGenerator',
#                 'generatedAt': '2023-11-10T02:45:45+00:00',
#                 'periods': [{'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -0.5555555555555556},
#                              'endTime': '2023-11-09T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 1,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 48},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-09T20:00:00-06:00',
#                              'temperature': 50,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '2 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0},
#                              'endTime': '2023-11-09T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 2,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 50},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-09T21:00:00-06:00',
#                              'temperature': 50,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '2 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -0.5555555555555556},
#                              'endTime': '2023-11-09T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,2?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 3,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 2},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 50},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-09T22:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '2 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -0.5555555555555556},
#                              'endTime': '2023-11-10T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 4,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 51},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-09T23:00:00-06:00',
#                              'temperature': 48,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0},
#                              'endTime': '2023-11-10T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 5,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 54},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-10T00:00:00-06:00',
#                              'temperature': 48,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 6,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 51},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-10T01:00:00-06:00',
#                              'temperature': 47,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 7,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 51},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-10T02:00:00-06:00',
#                              'temperature': 47,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '3 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 8,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 53},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-10T03:00:00-06:00',
#                              'temperature': 46,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 9,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 55},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-10T04:00:00-06:00',
#                              'temperature': 45,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 10,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 60},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-10T05:00:00-06:00',
#                              'temperature': 43,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 11,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 60},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-10T06:00:00-06:00',
#                              'temperature': 43,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 12,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 57},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T07:00:00-06:00',
#                              'temperature': 44,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T09:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 13,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 51},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T08:00:00-06:00',
#                              'temperature': 47,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T10:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 14,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 46},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T09:00:00-06:00',
#                              'temperature': 50,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T11:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 15,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 43},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T10:00:00-06:00',
#                              'temperature': 52,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-10T12:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 16,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 38},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T11:00:00-06:00',
#                              'temperature': 55,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-10T13:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 17,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 34},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T12:00:00-06:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -2.2222222222222223},
#                              'endTime': '2023-11-10T14:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 18,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 30},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T13:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -2.7777777777777777},
#                              'endTime': '2023-11-10T15:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 19,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 29},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T14:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.3333333333333335},
#                              'endTime': '2023-11-10T16:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 20,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 29},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T15:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -2.7777777777777777},
#                              'endTime': '2023-11-10T17:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 21,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 32},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T16:00:00-06:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -2.2222222222222223},
#                              'endTime': '2023-11-10T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 22,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 38},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-10T17:00:00-06:00',
#                              'temperature': 53,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '7 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-10T19:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 23,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 44},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-10T18:00:00-06:00',
#                              'temperature': 50,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-10T20:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 24,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 47},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-10T19:00:00-06:00',
#                              'temperature': 48,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-10T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 25,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 51},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-10T20:00:00-06:00',
#                              'temperature': 46,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-10T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 26,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 55},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-10T21:00:00-06:00',
#                              'temperature': 44,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-10T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 27,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 57},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-10T22:00:00-06:00',
#                              'temperature': 43,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-11T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 28,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 62},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-10T23:00:00-06:00',
#                              'temperature': 41,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-11T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 29,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 64},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-11T00:00:00-06:00',
#                              'temperature': 40,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-11T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 30,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 67},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-11T01:00:00-06:00',
#                              'temperature': 39,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-11T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 31,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 70},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-11T02:00:00-06:00',
#                              'temperature': 38,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-11T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 32,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 72},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-11T03:00:00-06:00',
#                              'temperature': 37,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-11T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 33,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 75},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-11T04:00:00-06:00',
#                              'temperature': 36,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-11T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 34,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 82},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-11T05:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-11T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 35,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 82},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-11T06:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -0.5555555555555556},
#                              'endTime': '2023-11-11T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 36,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 82},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-11T07:00:00-06:00',
#                              'temperature': 36,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'E',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0},
#                              'endTime': '2023-11-11T09:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 37,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-11T08:00:00-06:00',
#                              'temperature': 39,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'E',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0.5555555555555556},
#                              'endTime': '2023-11-11T10:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 38,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 70},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-11T09:00:00-06:00',
#                              'temperature': 42,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'E',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0.5555555555555556},
#                              'endTime': '2023-11-11T11:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 39,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 60},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-11T10:00:00-06:00',
#                              'temperature': 46,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'E',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0},
#                              'endTime': '2023-11-11T12:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 40,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
# ...
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-15T20:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 144,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 64},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-15T19:00:00-06:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-15T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 145,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 69},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-15T20:00:00-06:00',
#                              'temperature': 52,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-15T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 146,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 71},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-15T21:00:00-06:00',
#                              'temperature': 51,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-15T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 147,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 71},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-15T22:00:00-06:00',
#                              'temperature': 51,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,6?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 148,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 6},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 66},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-15T23:00:00-06:00',
#                              'temperature': 53,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 149,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 66},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-16T00:00:00-06:00',
#                              'temperature': 53,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 150,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 71},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-16T01:00:00-06:00',
#                              'temperature': 51,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 151,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 77},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-16T02:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 152,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 83},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-16T03:00:00-06:00',
#                              'temperature': 47,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 153,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 83},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-16T04:00:00-06:00',
#                              'temperature': 47,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 154,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 3},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 80},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-16T05:00:00-06:00',
#                              'temperature': 48,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct,2?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 155,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 2},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 77},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-16T06:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 6.111111111111111},
#                              'endTime': '2023-11-16T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct,2?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 156,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 2},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 77},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-16T07:00:00-06:00',
#                              'temperature': 50,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'}],
#                 'units': 'us',
#                 'updateTime': '2023-11-10T02:07:03+00:00',
#                 'updated': '2023-11-10T02:07:03+00:00',
#                 'validTimes': '2023-11-09T20:00:00+00:00/P7DT5H'},
#  'type': 'Feature'}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pprint(data)
#
# TypeError: 'module' object is not callable
