# %%
import requests
from pprint import pprint
import pandas as pd

# %%
# Replace with your desired latitude and longitude
latitude = '38.685066'
longitude = '-90.349317'

# Construct API endpoint URL
url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Construct the API endpoint URL for the given point
point_url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Make a GET request to the API for the given point
point_response = requests.get(point_url)

# Check if the request was successful
if point_response.status_code == 200:
    
    # Parse the JSON response
    point_data = point_response.json()
    pprint(point_data)
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'bearing': {'@type': 's:QuantitativeValue'},
#                'city': 's:addressLocality',
#                'county': {'@type': '@id'},
#                'distance': {'@id': 's:Distance',
#                             '@type': 's:QuantitativeValue'},
#                'forecastGridData': {'@type': '@id'},
#                'forecastOffice': {'@type': '@id'},
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'geometry': {'@id': 's:GeoCoordinates',
#                             '@type': 'geo:wktLiteral'},
#                'publicZone': {'@type': '@id'},
#                's': 'https://schema.org/',
#                'state': 's:addressRegion',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#                'value': {'@id': 's:value'},
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [-90.3493, 38.6851], 'type': 'Point'},
#  'id': 'https://api.weather.gov/points/38.6851,-90.3493',
#  'properties': {'@id': 'https://api.weather.gov/points/38.6851,-90.3493',
#                 '@type': 'wx:Point',
#                 'county': 'https://api.weather.gov/zones/county/MOC189',
#                 'cwa': 'LSX',
#                 'fireWeatherZone': 'https://api.weather.gov/zones/fire/MOZ063',
#                 'forecast': 'https://api.weather.gov/gridpoints/LSX/90,77/forecast',
#                 'forecastGridData': 'https://api.weather.gov/gridpoints/LSX/90,77',
#                 'forecastHourly': 'https://api.weather.gov/gridpoints/LSX/90,77/forecast/hourly',
#                 'forecastOffice': 'https://api.weather.gov/offices/LSX',
#                 'forecastZone': 'https://api.weather.gov/zones/forecast/MOZ063',
#                 'gridId': 'LSX',
#                 'gridX': 90,
#                 'gridY': 77,
#                 'observationStations': 'https://api.weather.gov/gridpoints/LSX/90,77/stations',
#                 'radarStation': 'KLSX',
#                 'relativeLocation': {'geometry': {'coordinates': [-90.340013,
#                                                                   38.68911],
#                                                   'type': 'Point'},
#                                      'properties': {'bearing': {'unitCode': 'wmoUnit:degree_(angle)',
#                                                                 'value': 241},
#                                                     'city': 'Vinita Park',
#                                                     'distance': {'unitCode': 'wmoUnit:m',
#                                                                  'value': 921.17913613927},
#                                                     'state': 'MO'},
#                                      'type': 'Feature'},
#                 'timeZone': 'America/Chicago'},
#  'type': 'Feature'}

# %%
# Replace with your desired latitude and longitude
latitude = '38.685066'
longitude = '-90.349317'

# Construct API endpoint URL
url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Construct the API endpoint URL for the given point
point_url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Make a GET request to the API for the given point
point_response = requests.get(point_url)

# Check if the request was successful
if point_response.status_code == 200:
    
    # Parse the JSON response
    point_data = point_response.json()

    # Extract the hourly forecast URL
    hourly_forecast_url = point_data['properties']['forecast']

    # Make a GET request to the hourly forecast URL
    hourly_forecast_response = requests.get(hourly_forecast_url)

    # Check if the hourly forecast request was successful
    if hourly_forecast_response.status_code == 200:
        # Parse the JSON response
        hourly_forecast_data = hourly_forecast_response.json()

        # Now hourly_forecast_data contains the hourly forecast information
        # You can print it out or process it as needed
        pprint(hourly_forecast_data)
    else:
        print(f'Error retrieving hourly forecast: {hourly_forecast_response.status_code}')
else:
    print(f'Error retrieving point data: {point_response.status_code}')
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [[[-90.3562231, 38.7005791],
#                                [-90.35719519999999, 38.6784337],
#                                [-90.32881509999999, 38.6776724],
#                                [-90.32783709999998, 38.699817599999996],
#                                [-90.3562231, 38.7005791]]],
#               'type': 'Polygon'},
#  'properties': {'elevation': {'unitCode': 'wmoUnit:m', 'value': 180.1368},
#                 'forecastGenerator': 'BaselineForecastGenerator',
#                 'generatedAt': '2023-11-16T02:02:50+00:00',
#                 'periods': [{'detailedForecast': 'Mostly clear, with a low '
#                                                  'around 45. South wind around '
#                                                  '6 mph.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=medium',
#                              'isDaytime': False,
#                              'name': 'Tonight',
#                              'number': 1,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 82},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-15T20:00:00-06:00',
#                              'temperature': 45,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': 'Sunny. High near 70, with '
#                                                  'temperatures falling to '
#                                                  'around 64 in the afternoon. '
#                                                  'South wind 6 to 14 mph, with '
#                                                  'gusts as high as 23 mph.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10.555555555555555},
#                              'endTime': '2023-11-16T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#                              'isDaytime': True,
#                              'name': 'Thursday',
#                              'number': 2,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 89},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T06:00:00-06:00',
#                              'temperature': 70,
#                              'temperatureTrend': 'falling',
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 to 14 mph'},
#                             {'detailedForecast': 'A chance of rain showers '
#                                                  'between 1am and 4am, then a '
#                                                  'slight chance of rain. '
#                                                  'Mostly cloudy, with a low '
#                                                  'around 55. Southwest wind '
#                                                  'around 10 mph, with gusts as '
#                                                  'high as 24 mph. Chance of '
#                                                  'precipitation is 20%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn/rain,20?size=medium',
#                              'isDaytime': False,
#                              'name': 'Thursday Night',
#                              'number': 3,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 20},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 90},
#                              'shortForecast': 'Mostly Cloudy then Slight '
#                                               'Chance Light Rain',
#                              'startTime': '2023-11-16T18:00:00-06:00',
#                              'temperature': 55,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': 'A chance of rain before '
#                                                  'noon. Partly sunny. High '
#                                                  'near 60, with temperatures '
#                                                  'falling to around 52 in the '
#                                                  'afternoon. Northwest wind '
#                                                  'around 12 mph. Chance of '
#                                                  'precipitation is 30%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,30/bkn?size=medium',
#                              'isDaytime': True,
#                              'name': 'Friday',
#                              'number': 4,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 30},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 90},
#                              'shortForecast': 'Chance Light Rain then Partly '
#                                               'Sunny',
#                              'startTime': '2023-11-17T06:00:00-06:00',
#                              'temperature': 60,
#                              'temperatureTrend': 'falling',
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': 'Clear, with a low around 32. '
#                                                  'North wind 6 to 9 mph.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-18T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#                              'isDaytime': False,
#                              'name': 'Friday Night',
#                              'number': 5,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 63},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-17T18:00:00-06:00',
#                              'temperature': 32,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '6 to 9 mph'},
#                             {'detailedForecast': 'Sunny. High near 55, with '
#                                                  'temperatures falling to '
#                                                  'around 50 in the afternoon.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.888888888888889},
#                              'endTime': '2023-11-18T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#                              'isDaytime': True,
#                              'name': 'Saturday',
#                              'number': 6,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 64},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-18T06:00:00-06:00',
#                              'temperature': 55,
#                              'temperatureTrend': 'falling',
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': 'Mostly clear, with a low '
#                                                  'around 36.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.3333333333333335},
#                              'endTime': '2023-11-19T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=medium',
#                              'isDaytime': False,
#                              'name': 'Saturday Night',
#                              'number': 7,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 64},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-18T18:00:00-06:00',
#                              'temperature': 36,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': 'Mostly sunny, with a high '
#                                                  'near 59.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-19T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#                              'isDaytime': True,
#                              'name': 'Sunday',
#                              'number': 8,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 64},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-19T06:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 to 9 mph'},
#                             {'detailedForecast': 'A chance of rain. Mostly '
#                                                  'cloudy, with a low around '
#                                                  '42. Chance of precipitation '
#                                                  'is 40%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 1.1111111111111112},
#                              'endTime': '2023-11-20T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,40?size=medium',
#                              'isDaytime': False,
#                              'name': 'Sunday Night',
#                              'number': 9,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 40},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 70},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-19T18:00:00-06:00',
#                              'temperature': 42,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': 'Rain likely. Mostly cloudy, '
#                                                  'with a high near 52. Chance '
#                                                  'of precipitation is 60%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 6.111111111111111},
#                              'endTime': '2023-11-20T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,40/rain,60?size=medium',
#                              'isDaytime': True,
#                              'name': 'Monday',
#                              'number': 10,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 60},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 80},
#                              'shortForecast': 'Light Rain Likely',
#                              'startTime': '2023-11-20T06:00:00-06:00',
#                              'temperature': 52,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'E',
#                              'windSpeed': '13 mph'},
#                             {'detailedForecast': 'A chance of rain. Mostly '
#                                                  'cloudy, with a low around '
#                                                  '41. Chance of precipitation '
#                                                  'is 50%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 6.666666666666667},
#                              'endTime': '2023-11-21T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,50/rain,30?size=medium',
#                              'isDaytime': False,
#                              'name': 'Monday Night',
#                              'number': 11,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 50},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 96},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-20T18:00:00-06:00',
#                              'temperature': 41,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '12 to 15 mph'},
#                             {'detailedForecast': 'A chance of rain. Partly '
#                                                  'sunny, with a high near 49. '
#                                                  'Chance of precipitation is '
#                                                  '30%.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5},
#                              'endTime': '2023-11-21T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,30?size=medium',
#                              'isDaytime': True,
#                              'name': 'Tuesday',
#                              'number': 12,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 30},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 96},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-21T06:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '18 mph'},
#                             {'detailedForecast': 'Partly cloudy, with a low '
#                                                  'around 33.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 2.7777777777777777},
#                              'endTime': '2023-11-22T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#                              'isDaytime': False,
#                              'name': 'Tuesday Night',
#                              'number': 13,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-21T18:00:00-06:00',
#                              'temperature': 33,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '14 to 17 mph'},
#                             {'detailedForecast': 'Sunny, with a high near 49.',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -2.7777777777777777},
#                              'endTime': '2023-11-22T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#                              'isDaytime': True,
#                              'name': 'Wednesday',
#                              'number': 14,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': None},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 69},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-22T06:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '14 mph'}],
#                 'units': 'us',
#                 'updateTime': '2023-11-15T22:52:09+00:00',
#                 'updated': '2023-11-15T22:52:09+00:00',
#                 'validTimes': '2023-11-15T16:00:00+00:00/P7DT9H'},
#  'type': 'Feature'}

# %%
# Replace with your desired latitude and longitude
latitude = '38.685066'
longitude = '-90.349317'

# Construct API endpoint URL
url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Construct the API endpoint URL for the given point
point_url = f'https://api.weather.gov/points/{latitude},{longitude}'

# Make a GET request to the API for the given point
point_response = requests.get(point_url)

# Check if the request was successful
if point_response.status_code == 200:
    
    # Parse the JSON response
    point_data = point_response.json()

    # Extract the hourly forecast URL
    hourly_forecast_url = point_data['properties']['forecastHourly']

    # Make a GET request to the hourly forecast URL
    hourly_forecast_response = requests.get(hourly_forecast_url)

    # Check if the hourly forecast request was successful
    if hourly_forecast_response.status_code == 200:
        # Parse the JSON response
        hourly_forecast_data = hourly_forecast_response.json()

        # Now hourly_forecast_data contains the hourly forecast information
        # You can print it out or process it as needed
        pprint(hourly_forecast_data)
    else:
        print(f'Error retrieving hourly forecast: {hourly_forecast_response.status_code}')
else:
    print(f'Error retrieving point data: {point_response.status_code}')
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [[[-90.3562231, 38.7005791],
#                                [-90.35719519999999, 38.6784337],
#                                [-90.32881509999999, 38.6776724],
#                                [-90.32783709999998, 38.699817599999996],
#                                [-90.3562231, 38.7005791]]],
#               'type': 'Polygon'},
#  'properties': {'elevation': {'unitCode': 'wmoUnit:m', 'value': 180.1368},
#                 'forecastGenerator': 'HourlyForecastGenerator',
#                 'generatedAt': '2023-11-16T02:43:36+00:00',
#                 'periods': [{'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 2.7777777777777777},
#                              'endTime': '2023-11-15T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 1,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 59},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-15T20:00:00-06:00',
#                              'temperature': 51,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 2.7777777777777777},
#                              'endTime': '2023-11-15T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 2,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 61},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-15T21:00:00-06:00',
#                              'temperature': 50,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.3333333333333335},
#                              'endTime': '2023-11-15T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 3,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 66},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-15T22:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.3333333333333335},
#                              'endTime': '2023-11-16T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 4,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 68},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-15T23:00:00-06:00',
#                              'temperature': 48,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.3333333333333335},
#                              'endTime': '2023-11-16T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 5,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 71},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-16T00:00:00-06:00',
#                              'temperature': 47,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.888888888888889},
#                              'endTime': '2023-11-16T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 6,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-16T01:00:00-06:00',
#                              'temperature': 46,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.888888888888889},
#                              'endTime': '2023-11-16T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 7,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 79},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-16T02:00:00-06:00',
#                              'temperature': 45,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.3333333333333335},
#                              'endTime': '2023-11-16T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 8,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 79},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-16T03:00:00-06:00',
#                              'temperature': 44,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.888888888888889},
#                              'endTime': '2023-11-16T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 9,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 79},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-16T04:00:00-06:00',
#                              'temperature': 45,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.3333333333333335},
#                              'endTime': '2023-11-16T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/skc,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 10,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Clear',
#                              'startTime': '2023-11-16T05:00:00-06:00',
#                              'temperature': 45,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 3.888888888888889},
#                              'endTime': '2023-11-16T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 11,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T06:00:00-06:00',
#                              'temperature': 46,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 5.555555555555555},
#                              'endTime': '2023-11-16T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 12,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 89},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T07:00:00-06:00',
#                              'temperature': 45,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 6.666666666666667},
#                              'endTime': '2023-11-16T09:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 13,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 83},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T08:00:00-06:00',
#                              'temperature': 49,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '6 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 7.777777777777778},
#                              'endTime': '2023-11-16T10:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 14,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 74},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T09:00:00-06:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 8.333333333333334},
#                              'endTime': '2023-11-16T11:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 15,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 67},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T10:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 8.88888888888889},
#                              'endTime': '2023-11-16T12:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/skc,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 16,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 60},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T11:00:00-06:00',
#                              'temperature': 62,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 9.444444444444445},
#                              'endTime': '2023-11-16T13:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 17,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 56},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T12:00:00-06:00',
#                              'temperature': 65,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '13 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 9.444444444444445},
#                              'endTime': '2023-11-16T14:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 18,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 54},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T13:00:00-06:00',
#                              'temperature': 66,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '13 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10},
#                              'endTime': '2023-11-16T15:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 19,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 52},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-16T14:00:00-06:00',
#                              'temperature': 68,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '14 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10},
#                              'endTime': '2023-11-16T16:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 20,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 52},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-16T15:00:00-06:00',
#                              'temperature': 68,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '14 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10.555555555555555},
#                              'endTime': '2023-11-16T17:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 21,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 58},
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2023-11-16T16:00:00-06:00',
#                              'temperature': 66,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '13 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10.555555555555555},
#                              'endTime': '2023-11-16T18:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 22,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 63},
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2023-11-16T17:00:00-06:00',
#                              'temperature': 64,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10.555555555555555},
#                              'endTime': '2023-11-16T19:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 23,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 67},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-16T18:00:00-06:00',
#                              'temperature': 62,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10.555555555555555},
#                              'endTime': '2023-11-16T20:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,0?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 24,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 0},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 72},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-16T19:00:00-06:00',
#                              'temperature': 60,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.11111111111111},
#                              'endTime': '2023-11-16T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 25,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 78},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-16T20:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-16T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn,1?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 26,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 1},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 80},
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2023-11-16T21:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-16T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,2?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 27,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 2},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 80},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-16T22:00:00-06:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-17T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,10?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 28,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 10},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 83},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-16T23:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,10?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 29,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 10},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 86},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-17T00:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-17T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain_showers,11?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 30,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 11},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 83},
#                              'shortForecast': 'Chance Rain Showers',
#                              'startTime': '2023-11-17T01:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain_showers,12?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 31,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 12},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 86},
#                              'shortForecast': 'Chance Rain Showers',
#                              'startTime': '2023-11-17T02:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain_showers,13?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 32,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 13},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 86},
#                              'shortForecast': 'Chance Rain Showers',
#                              'startTime': '2023-11-17T03:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/ovc,10?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 33,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 10},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 86},
#                              'shortForecast': 'Cloudy',
#                              'startTime': '2023-11-17T04:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain,16?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 34,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 16},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 90},
#                              'shortForecast': 'Slight Chance Light Rain',
#                              'startTime': '2023-11-17T05:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '8 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,31?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 35,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 31},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 90},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-17T06:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '9 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.777777777777779},
#                              'endTime': '2023-11-17T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,31?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 36,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 31},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 90},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-17T07:00:00-06:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 12.222222222222221},
#                              'endTime': '2023-11-17T09:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,31?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 37,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 31},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 90},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-17T08:00:00-06:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 11.666666666666666},
#                              'endTime': '2023-11-17T10:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,31?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 38,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 31},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 86},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-17T09:00:00-06:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 10},
#                              'endTime': '2023-11-17T11:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,31?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 39,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 31},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 77},
#                              'shortForecast': 'Chance Light Rain',
#                              'startTime': '2023-11-17T10:00:00-06:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '12 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 8.333333333333334},
#                              'endTime': '2023-11-17T12:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain,31?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 40,
# ...
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '17 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 2.2222222222222223},
#                              'endTime': '2023-11-21T20:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 144,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 9},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-21T19:00:00-06:00',
#                              'temperature': 43,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '17 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 1.6666666666666667},
#                              'endTime': '2023-11-21T21:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 145,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 9},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-21T20:00:00-06:00',
#                              'temperature': 42,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '17 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 1.1111111111111112},
#                              'endTime': '2023-11-21T22:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 146,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 9},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-21T21:00:00-06:00',
#                              'temperature': 41,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '17 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0.5555555555555556},
#                              'endTime': '2023-11-21T23:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 147,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 9},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 76},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-21T22:00:00-06:00',
#                              'temperature': 40,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '17 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': 0},
#                              'endTime': '2023-11-22T00:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 148,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 9},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 73},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-21T23:00:00-06:00',
#                              'temperature': 40,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '16 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -0.5555555555555556},
#                              'endTime': '2023-11-22T01:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,5?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 149,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 73},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-22T00:00:00-06:00',
#                              'temperature': 39,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '16 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.1111111111111112},
#                              'endTime': '2023-11-22T02:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,5?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 150,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 73},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-22T01:00:00-06:00',
#                              'temperature': 38,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '16 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -1.6666666666666667},
#                              'endTime': '2023-11-22T03:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct,5?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 151,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 72},
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2023-11-22T02:00:00-06:00',
#                              'temperature': 37,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '15 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -2.2222222222222223},
#                              'endTime': '2023-11-22T04:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,5?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 152,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 72},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T03:00:00-06:00',
#                              'temperature': 36,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '15 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -2.7777777777777777},
#                              'endTime': '2023-11-22T05:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,5?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 153,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 72},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T04:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '15 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.3333333333333335},
#                              'endTime': '2023-11-22T06:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few,5?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 154,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 69},
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2023-11-22T05:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '14 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.3333333333333335},
#                              'endTime': '2023-11-22T07:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,5?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 155,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 69},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-22T06:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '14 mph'},
#                             {'detailedForecast': '',
#                              'dewpoint': {'unitCode': 'wmoUnit:degC',
#                                           'value': -3.3333333333333335},
#                              'endTime': '2023-11-22T08:00:00-06:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few,5?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 156,
#                              'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#                                                             'value': 5},
#                              'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#                                                   'value': 69},
#                              'shortForecast': 'Sunny',
#                              'startTime': '2023-11-22T07:00:00-06:00',
#                              'temperature': 35,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NW',
#                              'windSpeed': '14 mph'}],
#                 'units': 'us',
#                 'updateTime': '2023-11-16T02:07:07+00:00',
#                 'updated': '2023-11-16T02:07:07+00:00',
#                 'validTimes': '2023-11-15T20:00:00+00:00/P7DT5H'},
#  'type': 'Feature'}

# %%
df = pd.read_csv('https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station=IKV&data=all&year1=2023&month1=1&day1=1&year2=2023&month2=11&day2=15&tz=Etc%2FUTC&format=onlycomma&latlon=no&elev=no&missing=M&trace=T&direct=no&report_type=3&report_type=4')
df.head()
# Out:
#   station             valid   tmpf   dwpf    relh    drct  sknt  p01i   alti  \
# 0     IKV  2023-01-01 00:15  35.60  33.80   93.08    0.00  0.00   0.0  29.75
# 1     IKV  2023-01-01 00:35  35.60  32.00   86.59  120.00  4.00   0.0  29.75
# 2     IKV  2023-01-01 00:55  33.80  32.00   93.03  130.00  5.00   0.0  29.75
# 3     IKV  2023-01-01 01:15  33.80  33.80  100.00    0.00  0.00   0.0  29.76
# 4     IKV  2023-01-01 01:35  33.80  32.00   93.03   40.00  4.00   0.0  29.76
#
#   mslp  ... wxcodes ice_accretion_1hr ice_accretion_3hr ice_accretion_6hr  \
# 0    M  ...       M                 M                 M                 M
# 1    M  ...       M                 M                 M                 M
# 2    M  ...       M                 M                 M                 M
# 3    M  ...       M                 M                 M                 M
# 4    M  ...       M                 M                 M                 M
#
#   peak_wind_gust peak_wind_drct peak_wind_time   feel  \
# 0              M              M              M  35.60
# 1              M              M              M  31.62
# 2              M              M              M  28.53
# 3              M              M              M  33.80
# 4              M              M              M  29.52
#
#                                                metar snowdepth
# 0  KIKV 010015Z AUTO 00000KT 10SM CLR 02/01 A2975...         M
# 1  KIKV 010035Z AUTO 12004KT 10SM BKN100 BKN120 0...         M
# 2  KIKV 010055Z AUTO 13005KT 9SM OVC100 01/00 A29...         M
# 3  KIKV 010115Z AUTO 00000KT 9SM FEW075 OVC100 01...         M
# 4  KIKV 010135Z AUTO 04004KT 9SM FEW075 OVC100 01...         M
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['station', 'valid', 'tmpf', 'dwpf', 'relh', 'drct', 'sknt', 'p01i',
#        'alti', 'mslp', 'vsby', 'gust', 'skyc1', 'skyc2', 'skyc3', 'skyc4',
#        'skyl1', 'skyl2', 'skyl3', 'skyl4', 'wxcodes', 'ice_accretion_1hr',
#        'ice_accretion_3hr', 'ice_accretion_6hr', 'peak_wind_gust',
#        'peak_wind_drct', 'peak_wind_time', 'feel', 'metar', 'snowdepth'],
#       dtype='object')

# %%
# I/relh - F/relativeHumidity
# I/tmpf - F/Temperature
# I/dwpf - F/dewpoint-> value
# I/sknt - F/windSpeed
# I/skyc1 - F/shortForecast
# I/valid - F/isDaytime
# I/p01i - F/probabilityOfPercipitation -> value

# %%
historic_weather = df.drop(columns = ['station','drct',
       'alti', 'mslp', 'vsby', 'gust',
       'skyl1', 'skyl2', 'skyl3', 'skyl4', 'wxcodes', 'skyc2', 'skyc3', 'skyc4', 'ice_accretion_1hr',
       'ice_accretion_3hr', 'ice_accretion_6hr', 'peak_wind_gust',
       'peak_wind_drct', 'peak_wind_time', 'feel', 'metar', 'snowdepth'])
historic_weather.head()
# Out:
#               valid   tmpf   dwpf    relh  sknt  p01i skyc1
# 0  2023-01-01 00:15  35.60  33.80   93.08  0.00   0.0   CLR
# 1  2023-01-01 00:35  35.60  32.00   86.59  4.00   0.0   BKN
# 2  2023-01-01 00:55  33.80  32.00   93.03  5.00   0.0   OVC
# 3  2023-01-01 01:15  33.80  33.80  100.00  0.00   0.0   FEW
# 4  2023-01-01 01:35  33.80  32.00   93.03  4.00   0.0   FEW

# %%
forecast  = []

periods_data = hourly_forecast_data['properties']['periods']
for period in periods_data:
    forecast.append({
        'Relative Humidity': period['relativeHumidity']['value'],
        'Temperature':period['temperature'],
        'Dewpoint': period['dewpoint']['value'],
        'Wind Speed': period['windSpeed'],
        'Short Forecast': period['shortForecast'],
        'Is Daytime':period['isDaytime'],
        'Probability of Percipitation':period['probabilityOfPrecipitation']['value']
    })
forecast_weather = pd.DataFrame(forecast)
forecast_weather.head()
# Out:
#    Relative Humidity  Temperature  Dewpoint Wind Speed Short Forecast  \
# 0                 59           51  2.777778      6 mph   Mostly Clear
# 1                 61           50  2.777778      6 mph   Mostly Clear
# 2                 66           49  3.333333      6 mph  Partly Cloudy
# 3                 68           48  3.333333      6 mph  Partly Cloudy
# 4                 71           47  3.333333      6 mph  Partly Cloudy
#
#    Is Daytime  Probability of Percipitation
# 0       False                             0
# 1       False                             0
# 2       False                             0
# 3       False                             0
# 4       False                             0

# %%
forecast_weather['Short Forecast'].unique()
# Out:
# array(['Mostly Clear', 'Partly Cloudy', 'Clear', 'Sunny', 'Mostly Sunny',
#        'Partly Sunny', 'Mostly Cloudy', 'Cloudy', 'Chance Rain Showers',
#        'Slight Chance Light Rain', 'Chance Light Rain',
#        'Light Rain Likely'], dtype=object)

# %%
def mapping(forecast):
    mapping = {'Mostly Clear': 'FEW',
        'Partly Cloudy': 'SCT',
        'Clear': 'CLR',
        'Sunny': 'CLR',
        'Mostly Sunny': 'FEW',
        'Partly Sunny': 'SCT',
        'Mostly Cloudy': 'BKN',
        'Cloudy': 'OVC',
        'Chance Rain Showers': 'SCT',
        'Slight Chance Light Rain': 'SCT',
        'Chance Light Rain': 'SCT',
        'Light Rain Likely': 'BKN'
    }
    return mapping.get(forecast, 'Unknown')

forecast_weather['Mapped Forecast'] = forecast_weather['Short Forecast'].apply(mapping)
forecast_weather.head()
# Out:
#    Relative Humidity  Temperature  Dewpoint Wind Speed Short Forecast  \
# 0                 59           51  2.777778      6 mph   Mostly Clear
# 1                 61           50  2.777778      6 mph   Mostly Clear
# 2                 66           49  3.333333      6 mph  Partly Cloudy
# 3                 68           48  3.333333      6 mph  Partly Cloudy
# 4                 71           47  3.333333      6 mph  Partly Cloudy
#
#    Is Daytime  Probability of Percipitation Mapped Forecast
# 0       False                             0             FEW
# 1       False                             0             FEW
# 2       False                             0             SCT
# 3       False                             0             SCT
# 4       False                             0             SCT

# %%
forecast_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Relative Humidity             156 non-null    int64
#  1   Temperature                   156 non-null    int64
#  2   Dewpoint                      156 non-null    float64
#  3   Wind Speed                    156 non-null    object
#  4   Short Forecast                156 non-null    object
#  5   Is Daytime                    156 non-null    bool
#  6   Probability of Percipitation  156 non-null    int64
#  7   Mapped Forecast               156 non-null    object
# dtypes: bool(1), float64(1), int64(3), object(3)
# memory usage: 8.8+ KB

# %%
1historic_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22618 entries, 0 to 22617
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   valid   22618 non-null  object
#  1   tmpf    22618 non-null  object
#  2   dwpf    22618 non-null  object
#  3   relh    22618 non-null  object
#  4   sknt    22618 non-null  object
#  5   p01i    22618 non-null  float64
#  6   skyc1   22618 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.2+ MB
